# %%
import openai
openai.api_key = "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"

prompt = "Write a paragraph about the benefits of artificial intelligence."
model = "text-davinci-002"  # GPT-3 model to use
response = openai.Completion.create(
  prompt=prompt, model=model, max_tokens=1024
)
print(response.choices[0].text)

# %%
# !pip install spacy https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl

# %%
import spacy

text = "Apple Inc. is planning to release its latest iPhone in September. The company has postponed the launch due to manufacturing issues."

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

for ent in doc.ents:
  print(ent.text, ent.label_)

# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/fi_core_news_lg-3.5.0/fi_core_news_lg-3.5.0-py3-none-any.whl

# %%
nlp = spacy.load("fi_core_news_lg")

# %%
doc = nlp("""
Yhä useampi duunarityötä tekevä ihminen uhkaa ajautua köyhyyteen, selviää Suomen Ammattiliittojen keskusjärjestö SAK:n ja professori Juho Saaren tekemästä tutkimuksesta.

Tampereen yliopiston sosiaali- ja terveyspolitiikan professori Juho Saari ja SAK ovat selvittäneet, riittääkö duunarityötä tekevän palkka elämiseen nyky-Suomessa.

Kantar toteutti tutkimukseen liittyvän kyselyn. Siihen vastasi 1 009 suorittavaa työtä tekevää palkansaajaa tämän vuoden helmi–maaliskuussa.

Vaikka tiedossa oli, että työntekijöiden toimeentulo on vaikeutunut, tuli tutkimustulosten synkkyys silti yllätyksenä, SAK:n tutkimusasiantuntija Ari-Matti Näätänen sanoo.

”Meinasin pudota penkiltä, kun näin tulokset. Niiden mukaan useampi kuin joka kymmenes duunarityötä tekevä on suuressa köyhyysriskissä.”

Lukumääräisesti tämä tarkoittaa noin 100 000 ihmistä. Jos mukaan lasketaan melko suuressa köyhyysriskissä olevat, nousee luku 400 000:een. Tämä tarkoittaa, että duunarityötä tekevistä palkansaajista noin kolmannes on melko suuressa tai suuressa köyhyysriskissä.

Kantarin toteuttaman kyselyn mukaan itsensä duunariksi identifioi itsensä 1,3 miljoonaa palkansaajaa. Kyselyyn vastanneet työntekijät saivat itse määritellä, kokevatko he olevansa duunarityöntekijöitä.

Palkansaajia on noin 2,6 miljoonaa. Heistä noin puolet siis identifioi itsensä duunariksi subjektiivisen mittarin mukaan.

Lue lisää: Hintojen nousu on pudottanut köyhyyteen yli 60 000 suomalaista – Kun seuraukset paljastuivat, Silja purskahti itkuun

Sadallatuhannella palkansaajalla ei siis ole yhtään ylimääräistä rahaa, eikä minkäänlaisia puskureita.

”Jos näiden ihmisten käytettävissä olevat tulot laskisivat yhtään, niin tilanne olisi arjen selviytymisen kannalta katastrofaalinen”, sanoo Juho Saari.

Köyhyysriski on suurin palvelu- ja myyntityössä. Sen työntekijöistä 15 prosenttia on suuressa köyhyysriskissä ja 28 prosenttia melko suuressa köyhyysriskissä. Toiseksi suurin riski on prosessi- ja kuljetusalalla.

Köyhtyminen johtuu Saaren mukaan kohonneista elinkustannuksista ja siitä, että palkat eivät ole nousseet samaa tahtia hintojen kanssa.

”Tämä on johtanut siihen, että ne joilla ei ole alunperinkään ollut rahapuskuria ovat nyt tiukoilla ja niiden määrä, joilla ei enää ole puskuria kasvaa.”

Juho Saari on tutkinut duunariköyhyyttä yhdessä Ammattiliittojen keskusjärjestö SAK:n kanssa. Kuva: Heidi Piiroinen / HS

Perinteisesti työssäkäyvien köyhyyttä mitataan niin, että lasketaan palkkatyössä olevat ihmiset, jotka jäävät köyhyysrajan alapuolelle. Tällä mittaustavalla osa köyhyydestä jää kuitenkin piiloon.

Tässä tutkimuksessa köyhyyttä haluttiin tarkastella moniulotteisemmalla mittarilla. Tutkijat loivat kolme kriteeriä, joiden varassa he arvioivat duunareiden köyhyyttä.

Ensimmäinen niistä oli niukkuuden kokemus. Vastaajilta kysyttiin, riittävätkö tulot menoihin. Toinen kriteeri oli rahallinen puskuri. Tässä kysyttiin sitä, tekisikö se, että saisit kuussa käteen 250 euroa vähemmän elämästäsi mahdotonta. Kolmas kysymys koski lisätuloja. Miten 250 euron lisätulot vaikuttaisivat vastaajan elämään.

”Näillä mittareilla, jotka ovat arjen kannalta paljon olennaisempia kuin suhteellinen tulomittari, meillä on paljon duunariköyhiä”, sanoo Juho Saari.

Duunaripalkansaajista 31 prosenttia arvioi, että 250 euroa vähemmän kuussa tekisi heidän elämästään taloudellisesti käytännössä mahdotonta. Tämä tarkoittaa, että melkein joka kolmannella duunarilla talous ei kestäisi yllättäviä menoja, kuten pesukoneen tai puhelimen äkillistä rikkoutumista.

Tällä hetkellä moni yrittää selviytyä lisätöitä tekemällä, rahaa lainaamalla tai vähentämällä menoja. Pitkään jatkuessaan tilanne voi Saaren mukaan johtaa siihen, että ihmiset vetäytyvät työmarkkinoilta, jos työn tekeminen ei enää kannata.

”Se voi myös johtaa siihen, että yhä useampi ihminen on oikeutettu etuuksiin.”

Nyt julkaistu raportti on ensimmäinen osa laajempaa tutkimusta, jota on tarkoitus jatkaa kevään aikana tulonjako- ja palkka-aineistojen tutkimuksella ja SAK:n jäsenliitoille suunnatulla kyselyillä. Hanketta tehdään yhteistyössä Tampereen yliopiston Työelämän tutkimuskeskuksen kanssa.

”Yritämme kartoittaa sitä, kuinka isosta yhteiskunnallisesta ilmiöstä on kysymys ja miten ihmiset selviytyvät näissä tilanteissa”, kertoo Saari. 
""")

# %%
for ent in doc.ents:
  print(ent.text, ent.label_)

# %%
list(doc.noun_chunks)

# %%
for sent in doc.sents:
    print("-", sent)

# %%
doc.similarity(doc)

# %%
def analyze(s):
    doc = nlp(s)
    for ent in doc.ents:
        print(f"{ent.label_}: {ent.text} | {ent.lemma_}")

# %%
analyze("Mikä on seuraava yhteys kotoa Urheilupuistoon?")
# Out:
# LOC: Urheilupuistoon | Urheilupuistoon

# %%
analyze("Mikä on seuraava yhteys Visamäen pysäkiltä Espoon Urheilupuistoon?")
# Out:
# LOC: Visamäen | Visamäki
# FAC: Espoon Urheilupuistoon | Espoo Urheilupuisto

# %%
print(doc.text_with_ws)
# Out:
# Yhä useampi duunarityötä tekevä ihminen uhkaa ajautua köyhyyteen, selviää Suomen Ammattiliittojen keskusjärjestö SAK:n ja professori Juho Saaren tekemästä tutkimuksesta.
#
# Tampereen yliopiston sosiaali- ja terveyspolitiikan professori Juho Saari ja SAK ovat selvittäneet, riittääkö duunarityötä tekevän palkka elämiseen nyky-Suomessa.
#
# Kantar toteutti tutkimukseen liittyvän kyselyn. Siihen vastasi 1 009 suorittavaa työtä tekevää palkansaajaa tämän vuoden helmi–maaliskuussa.
#
# Vaikka tiedossa oli, että työntekijöiden toimeentulo on vaikeutunut, tuli tutkimustulosten synkkyys silti yllätyksenä, SAK:n tutkimusasiantuntija Ari-Matti Näätänen sanoo.
#
# ”Meinasin pudota penkiltä, kun näin tulokset. Niiden mukaan useampi kuin joka kymmenes duunarityötä tekevä on suuressa köyhyysriskissä.”
#
# Lukumääräisesti tämä tarkoittaa noin 100 000 ihmistä. Jos mukaan lasketaan melko suuressa köyhyysriskissä olevat, nousee luku 400 000:een. Tämä tarkoittaa, että duunarityötä tekevistä palkansaajista noin kolmannes on melko suuressa tai suuressa köyhyysriskissä.
#
# Kantarin toteuttaman kyselyn mukaan itsensä duunariksi identifioi itsensä 1,3 miljoonaa palkansaajaa. Kyselyyn vastanneet työntekijät saivat itse määritellä, kokevatko he olevansa duunarityöntekijöitä.
#
# Palkansaajia on noin 2,6 miljoonaa. Heistä noin puolet siis identifioi itsensä duunariksi subjektiivisen mittarin mukaan.
#
# Lue lisää: Hintojen nousu on pudottanut köyhyyteen yli 60 000 suomalaista – Kun seuraukset paljastuivat, Silja purskahti itkuun
#
# Sadallatuhannella palkansaajalla ei siis ole yhtään ylimääräistä rahaa, eikä minkäänlaisia puskureita.
#
# ”Jos näiden ihmisten käytettävissä olevat tulot laskisivat yhtään, niin tilanne olisi arjen selviytymisen kannalta katastrofaalinen”, sanoo Juho Saari.
#
# Köyhyysriski on suurin palvelu- ja myyntityössä. Sen työntekijöistä 15 prosenttia on suuressa köyhyysriskissä ja 28 prosenttia melko suuressa köyhyysriskissä. Toiseksi suurin riski on prosessi- ja kuljetusalalla.
#
# Köyhtyminen johtuu Saaren mukaan kohonneista elinkustannuksista ja siitä, että palkat eivät ole nousseet samaa tahtia hintojen kanssa.
#
# ”Tämä on johtanut siihen, että ne joilla ei ole alunperinkään ollut rahapuskuria ovat nyt tiukoilla ja niiden määrä, joilla ei enää ole puskuria kasvaa.”
#
# Juho Saari on tutkinut duunariköyhyyttä yhdessä Ammattiliittojen keskusjärjestö SAK:n kanssa. Kuva: Heidi Piiroinen / HS
#
# Perinteisesti työssäkäyvien köyhyyttä mitataan niin, että lasketaan palkkatyössä olevat ihmiset, jotka jäävät köyhyysrajan alapuolelle. Tällä mittaustavalla osa köyhyydestä jää kuitenkin piiloon.
#
# Tässä tutkimuksessa köyhyyttä haluttiin tarkastella moniulotteisemmalla mittarilla. Tutkijat loivat kolme kriteeriä, joiden varassa he arvioivat duunareiden köyhyyttä.
#
# Ensimmäinen niistä oli niukkuuden kokemus. Vastaajilta kysyttiin, riittävätkö tulot menoihin. Toinen kriteeri oli rahallinen puskuri. Tässä kysyttiin sitä, tekisikö se, että saisit kuussa käteen 250 euroa vähemmän elämästäsi mahdotonta. Kolmas kysymys koski lisätuloja. Miten 250 euron lisätulot vaikuttaisivat vastaajan elämään.
#
# ”Näillä mittareilla, jotka ovat arjen kannalta paljon olennaisempia kuin suhteellinen tulomittari, meillä on paljon duunariköyhiä”, sanoo Juho Saari.
#
# Duunaripalkansaajista 31 prosenttia arvioi, että 250 euroa vähemmän kuussa tekisi heidän elämästään taloudellisesti käytännössä mahdotonta. Tämä tarkoittaa, että melkein joka kolmannella duunarilla talous ei kestäisi yllättäviä menoja, kuten pesukoneen tai puhelimen äkillistä rikkoutumista.
#
# Tällä hetkellä moni yrittää selviytyä lisätöitä tekemällä, rahaa lainaamalla tai vähentämällä menoja. Pitkään jatkuessaan tilanne voi Saaren mukaan johtaa siihen, että ihmiset vetäytyvät työmarkkinoilta, jos työn tekeminen ei enää kannata.
#
# ”Se voi myös johtaa siihen, että yhä useampi ihminen on oikeutettu etuuksiin.”
#
# Nyt julkaistu raportti on ensimmäinen osa laajempaa tutkimusta, jota on tarkoitus jatkaa kevään aikana tulonjako- ja palkka-aineistojen tutkimuksella ja SAK:n jäsenliitoille suunnatulla kyselyillä. Hanketta tehdään yhteistyössä Tampereen yliopiston Työelämän tutkimuskeskuksen kanssa.
#
# ”Yritämme kartoittaa sitä, kuinka isosta yhteiskunnallisesta ilmiöstä on kysymys ja miten ihmiset selviytyvät näissä tilanteissa”, kertoo Saari.

# %%
for c in doc.noun_chunks:
    print(c.lemma_)
# Out:
# yhä usea duunarityö
# ihminen
# köyhyys
# Suomi Ammattiliittojen keskusjärjestö
# SAK
# professori Juho Saari
# tutkimus
# Tampere yliopisto sosiaali ja terveyspolitiika professori Juho Saari
# SAK
# duunarityö
# palkka eläminen
# Kantar
# tutkimus
# kysely
# 1 009 suorittava työ
# palkansaaja
# tämä vuosi helmi
# maaliskuu
# tieto
# työntekijös toimeentulo
# tutkimustulos synkkyys
# yllätyknen
# SAK tutkimusasiantuntija Ari-Matti Näätänen
# penkki
# tulos
# joka kymmenes duunarityö
# noin 100 000 ihminen
# suure köyhyysriskissä
# luku 400
# duunarityö
# kantari
# kysely
# 1,3 miljoona palkansaaja
# kyselyyn
# työntekijä
# duunarityöntekijö
# Palkansaaja
# Heistä noin puoli
# subjektiivinen mittari
# Hintojen nousu
# köyhyys
# yli 60 000 suomalainen
# seuraus
# Silja
# itku
# Sadallatuhannella
# palkansaaja
# ylimääräinen raha
# minkäänlainen puskure
# ihminen
# tulo
# tilanne
# arki selviytyminen kanta
# Juho Saari
# Köyhyysriski
# suuri palvelu
# myyntityö
# se työntekijö 15 prosentti
# suuri köyhyysriskissä
# 28 prosentti melko suure köyhyysriskissä
# suuri riski
# prosessi
# kuljetusala
# köyhtyminen
# Saari
# kohonneista elinkustannus
# se
# palkka
# tahtia
# hinta
# alunperinkään
# rahapuskuri
# olla nyt tiukoa ja se määrä
# puskuri
# Juho Saari
# duunariköyhyys
# ammattiliitto keskusjärjestö
# SAK
# kuva
# Heidi Piiroinen / HS
# työssäkäyva köyhyys
# palkkatyö
# ihminen
# köyhyysraja
# mittaustavalla
# osa köyhyyde
# piilo
# tutkimus
# köyhyys
# moniulotteisemma mittari
# tutkija
# kolme kriteeri
# duunareiden köyhyys
# niukkuus kokemus
# Vastaajilta
# tulo
# mena
# toinen kriteeri
# rahallinen puskuri
# kuu
# käsi
# kolmas kysymys
# lisätulo
# miten 250 euro lisätulo
# vastaaja elämä
# mittari
# duunariköyhiä
# Juho Saari
# Duunaripalkansaajista
# 31 prosentti
# kuu
# hän elämä
# kolmannella duunari
# talous
# yllättävä meno
# pesukone tai puhelin äkillinen rikkoutuminen
# hetki
# lisätyö
# raha
# meno
# tilanne
# Saari
# ihminen
# työmarkkinoilta
# työ tekeminen
# yhä usea ihminen
# etuuksi
# raportti
# ensimmäinen osa laaja tutkimus
# kevät aika
# tulonjako ja palkka-aineistojen tutkimus
# SAK jäsenliito
# kysely
# Hanketta
# yhteistyö
# Tampere yliopisto työelämä tutkimuskeskus
# iso yhteiskunnallinen ilmiö olla kysymys
# ihminen
# selviytyä
# tilanne
# Saari

# %%
for v in doc.vocab:
    print(v.norm_)
# Out:
# ü.
# se
# arvioi
# hintojen
# like_num
# rak.
#
# c.
# miten
# :-}
# hintojen
# puhelimen
# määritellä
# suomalaista
# elämästään
# toteutti
# tutkimuksessa
# enää
# flag50
# k.
# yhteiskunnallisesta
# puskuri
# e
# suhteellinen
# tekevä
# :-o
# joht
# n.
# yms
# arjen
# >.<
# mm.
# elämästäsi
# näillä
# espoon
# :-*
# vaikuttaisivat
# g.
# oikeutettu
# mutt
# :()
# )-:
# x
# rahapuskuria
# verb
# tark
# 0.o
# olevat
# euron
# raportti
# paljastuivat
# saivat
# ━
# (-_-)
# olennaisempia
# 0
# minkäänlaisia
# x.
# yhteistyössä
# ><(((*>
# -o
# jos
# huom
# deprecated047
# penkiltä
# aik
# 8-)
# "
# °c.
# b
# toimeentulo
# nousseet
# o.o
# lk.
# q.
# helmi
# tämän
# kuussa
# vaikk
# "
# yllätyksenä
# tutkinut
# per
# kannata
# yo.
# ts
# <space>
# h.
# heidi
# 15
# näissä
# vaikk
# noin
# ä
# olisi
# heistä
# purskahti
# tutkimuksella
# ;d
# myöh
# alunperinkään
# samaa
# vastanneet
# palkansaajia
# z.
# '
# suuressa
# miljoonaa
# ü
# r
# kestäisi
# ︵
# lkm.
# työmarkkinoilta
# selviytyvät
# tark.
# :-))
# ;_;
# tutkimusasiantuntija
# jott
# srk.
# vähemmän
# yhtään
# yo
# yhä
# voi
# o_o
# palkansaajalla
# kolme
# kokevatko
# o
# toinen
# pysäkiltä
# ._.
# :’-)
#
# puskuria
# joht.
# palkansaajaa
# 000
# |
# palkka
# :((
#
#
#
# xdd
# työntekijöistä
# niiden
# ei
# ml.
# lasketaan
# lisätulot
# hanketta
# g
# 400
# tutkimusta
# yliopp
# 000:een
# mahdotonta
# -
# (
# po
# ym
# seuraukset
# prof
# ns.
# (;
# köyhyysriski
# lisätöitä
# _
# jos
# jota
# eaa.
# □
# sanoo
# :p
# w
# katastrofaalinen
# kuten
# melkein
# :'-(
# siitä
# eivat
# nro
# urheilupuistoon
# as
# pvm.
# :-/
# silti
# suunnatulla
# nyky-suomessa
# prof.
# tutkimuksesta
# ;
# meillä
# a.
# :)))
# k
# o.
# xd
# kannalta
# palkansaajista
# c
# saaren
# >:o
# :-)
# <3
# d
# 8)
# toim.
# ari-matti
# emme
# vuoden
# tarkoittaa
# (¬_¬)
# palkka-aineistojen
# f
# v_v
# työntekijöiden
# :(((
# itsensä
# vetäytyvät
# ]
# -8
# c
# (^_^)
# milj.
# puh.joht
# :d
# n:o
# miks
# m
# kotoa
# äkillistä
# ?
# elinkustannuksista
# myyntityössä
# m.
# 8-
# nimim.
# 0_0
# tms.
# meinasin
# tekevää
# nyk.
# ¬_¬
# lue
# =
# f
# ao
# y
# :o
# per.
# 100
# joilla
# :|
# piiloon
# :1
# ilmiöstä
# 0.0
# pudottanut
# sitä
# kyselyn
# aik.
# tämä
# ko.
# =d
# loivat
# -0
# näin
# työn
# en
# vm.
# selvittäneet
# huom.
# .
# em.
# jott
# :o)
# ko
# \
# tekemällä
# h
# ಠ_ಠ
# ┻
# 0_o
# tilanteissa
# [=
# ä.
# liittyvän
# ö.
# ett
# se
# piiroinen
# :p
# työssäkäyvien
# :-(
# :-((
# <
# palkkatyössä
# jää
# o.o
# suorittavaa
# tarkastella
# suurin
# ja
# space
# ¯\(ツ)/¯
# duunarilla
# kevään
# miks
# menoja
# jne.
# t
# niukkuuden
# ark.
# =)
# a
# synkkyys
# subjektiivisen
# 1,3
# ovat
# moni
# 2,6
# /3
# tutkimustulosten
# mutt
# ihminen
# arvioivat
# hetkellä
# tulomittari
# *
# :x
# kuva
# kriteeriä
# ]=
# /
# ks
# vastaajan
# :(
# 8d
# j.
# näiden
# °k.
# julkaistu
# :-)))
# ao.
# mittaustavalla
# yli
# duunareiden
# jotka
# o_o
# o_o
# itse
# (-:
# :
# joll
# par.
# puh.
# palvelu-
# koivusyrjä
# =/
# ^_^
# [-:
# laajempaa
# siks
# (:
# vas
# alv.
# siihen
# he
# :-p
# pvm
# joiden
# 31
# tutkijat
# tekisi
# köyhyysriskissä
# ihmisten
# johtanut
# laskisivat
# =[
# vast.
# vaikka
# selviää
# '
# ell
# l
# elämiseen
# identifioi
# rikkoutumista
# u
# tampereen
# :-o
# q
# ;-)
# työtä
# rahaa
# rak
# til
# pj.
# köyhyydestä
# 333
# \n
# nousee
# f.
# selviytymisen
# b.
# v
# olevansa
# palkat
# tulonjako-
# =3
# tutkimuskeskuksen
# >.>
# ts.
# :}
# talous
# kyselyillä
# ajautua
# seuraava
# ark
# yht
# kolmas
# paljon
# ed
# siht
# :))
# duunariköyhyyttä
# j
# ehk
# työntekijät
# juho
# duunarityötä
# so
# köyhyysrajan
# joll
# duunariköyhiä
# \")
# tiedossa
# </3
# käytettävissä
# ^___^
# =|
# v_v
# mittarin
# siks
# tekevän
# :’-(
# sak:n
# duunarityöntekijöitä
# yliopiston
# puskureita
# tekisikö
# duunariksi
# (>_<)
# ammattiliittojen
# :'(
# saisit
# til.
# -o
# ette
# (=
# k.
# mm.
# eikä
# k
# perinteisesti
# oik.
# kysyttiin
# toiseksi
# :-3
# tms
# ed.
# vähentämällä
# kuinka
# melko
# o_0
# alv
#
# moniulotteisemmalla
# lainaamalla
# -__-
# n:o
# kokemus
# <333
# esim.
# (-;
# mm
# koski
# myös
# (o:
# =]
# heidän
# mukaan
# nousu
# saari
# v.v
# tällä
# -p
# vaikeutunut
# :x
# oli
# 60
# sen
# kartoittaa
# köyhyyttä
# "
# i.
# sosiaali-
# niin
# "
# 8-d
# :-d
# toim
# [
# kuljetusalalla
# 3:sta
# kolmannella
# kun
# ett
# -x
# maaliskuussa
# vrt
# myöh.
# työelämän
# miel
# \t
# kyselyyn
# d
# mitataan
# käytännössä
# 1
# pudota
# että
# haluttiin
# riittävätkö
# jatkaa
# (._.)
# läh.
# vastaajilta
# jäsenliitoille
# :-0
# tässä
# selviytyä
# nimim
# -p
# tekeminen
# ):
# ns
# ensimmäinen
# )
# köyhyyteen
# -|
# ne
# keskusjärjestö
# mikä
# c++
# ym.
# -d
# (-8
# w.
# riittääkö
# rahallinen
# f.
# jäävät
# ehk
# :]
# °k.
# lyh.
# pesukoneen
# -3
# e.
# v.v
# läh
# kolmannes
# näätänen
# os.
# visamäen
# yms.
# luku
# tekevistä
# euroa
# et
# mittareilla
# alk
# yritämme
# lisätuloja
# eaa
# °f.
# yrittää
# :')
# määrä
# nyt
# yliopp.
# -
# ;-d
# par
# 009
# miten
# °f.
# 28
# :>
# >
# d.
# :o
# o.o
# po.
# ╯
# :0
# professori
# yl
# os
# s
# ml
# vas.
# p.
# -/
# lisää
# ^__^
# p
# prosenttia
# alk.
# esim
# tuli
# jatkuessaan
# vrt.
# silja
# lukumääräisesti
# kohonneista
# siis
# menoihin
# >:(
# <.<
# °
# :’(
# itkuun
# puh
# tehdään
# isosta
# :’)
# so.
# elämään
# yht.
# tarkoitus
# tahtia
# niiden
# kuitenkin
# 8
# <33
# o_o
# n
# em
# }
# (*_*)
# (╯°□°）╯︵┻━┻
# ,
# on
# 3
# synt
# useampi
# kosk
# eivät
# as.
# :/
# sadallatuhannella
# yhteys
# x
# niistä
# aikana
# milj
# [:
# jne
# vast
# o
# puh.joht.
# :'-)
# siihen
# yhä
#
# ry.
# kysymys
# y.
# @_@
# käteen
# kantar
# tai
# :3
# lk
# terveyspolitiikan
# nyk
# puolet
# varassa
# lkm
# tiukoilla
# hs
# ಠ︵ಠ
# kasvaa
# 33
# ;)
# kertoo
# ell
# :-(((
# köyhtyminen
# ollut
# i
# vastasi
# -x
# xd
# suomen
# kymmenes
# t.
# srk
# kanssa
# °c.
# 250
# yhdessä
# siht.
# :-x
# ks.
# v.
# joka
# tulot
# yllättäviä
# tekemästä
# tutkimukseen
# :)
# z
# mm
# yl.
# -_-
# pj
# (ಠ_ಠ)
# nyt
# johtuu
# mittarilla
# ole
# duunaripalkansaajista
# :->
# kantarin
# sak
# vm
# riski
# ry
# kun
# ）
# johtaa
# ö
# o.0
# uhkaa
# r.
# kosk
# l.
# xdd
# p
# ihmiset
# s.
# osa
# c.
# :-x
# u.
# ylimääräistä
# prosessi-
# :-]
# tilanne
# pitkään
# oik
# =(
# ihmistä
# kriteeri
# o.o
# lyh
# ensimmäinen
# :-p
# tulokset
# -
# alapuolelle
#
#
# toteuttaman
# miel.
# :-|
# etuuksiin
# :*
# taloudellisesti
# tämä
# synt.
# kuin

# %%
v.norm_
# Out:
# 'kuin'

# %%
import spacy
from collections import Counter

nlp = spacy.load("en_core_web_sm")
doc = nlp("The quick brown fox jumps over the lazy dog. The dog barks back.")

noun_phrases = [chunk.text for chunk in doc.noun_chunks]
top_noun_phrases = Counter(noun_phrases).most_common(3)  # top 3 most common noun phrases

for np in top_noun_phrases:
  print(f"{np[0]}: {np[1]}")
# Out:
# The quick brown fox: 1
# the lazy dog: 1
# The dog: 1
